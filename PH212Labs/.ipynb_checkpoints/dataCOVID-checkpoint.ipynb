# %% [markdown]
# ## COVID Data: An Example of .csv Data
# ### PH 212 COCC
# #### Bruce Emerson 5/4/21
#
# As an illustration of the utility of accessing .csv data files this notebook explores the COVID data set maintained by the NY Times on it's github. The particular data I decided to work with is the county by county data from across the country for the most recent 30 days. This is a remarkably small file (a few MB) which tempts me to down load the full pandemic data set but I am resisting for now.
#
# [NY Times data github](https://github.com/nytimes/covid-19-data/blob/master/us-counties-recent.csv).

# %% [markdown]
# ### Dependencies
#
# The new dependency here is the [Pandas](https://pandas.pydata.org/) library which was developed to support data science applications in python. It is classically imported with the alias pd. It is installed as part of your Anaconda package. When you update Anaconda you can also update Pandas.

# %%
import numpy as np
import pandas as pd
import matplotlib as mplot
import matplotlib.pyplot as plt
from numpy.polynomial import polynomial as ply

# %% [markdown]
# ### Read csv from Pandas
#
# As we get deeper into python we will need to begin to develop a richer understanding of how python works. We can do this incrementally so don't panic. In Pandas there are a variety of [data structures](https://pandas.pydata.org/docs/user_guide/dsintro.html#dataframe) which are described in the pandas documentation. There is clearly a lot to learn be we will focus on [data frames](https://pandas.pydata.org/docs/user_guide/dsintro.html#dataframe) which are a data structure that matches our normal understanding of a two dimensional data set.

# %%
dataSet = pd.read_csv("data/us-counties-recent.csv")
print(dataSet)
# Out:
#              date      county    state     fips  cases  deaths
# 0      2021-04-04     Autauga  Alabama   1001.0   6619   102.0
# 1      2021-04-04     Baldwin  Alabama   1003.0  20541   301.0
# 2      2021-04-04     Barbour  Alabama   1005.0   2232    55.0
# 3      2021-04-04        Bibb  Alabama   1007.0   2546    58.0
# 4      2021-04-04      Blount  Alabama   1009.0   6459   132.0
# ...           ...         ...      ...      ...    ...     ...
# 97423  2021-05-03  Sweetwater  Wyoming  56037.0   4250    37.0
# 97424  2021-05-03       Teton  Wyoming  56039.0   3739     9.0
# 97425  2021-05-03       Uinta  Wyoming  56041.0   2195    12.0
# 97426  2021-05-03    Washakie  Wyoming  56043.0    905    26.0
# 97427  2021-05-03      Weston  Wyoming  56045.0    651     5.0
#
# [97428 rows x 6 columns]

# %% [markdown]
# ### Filter the Data Frame:
#
# This data file has COVID data from every county in the country for the last 30 days. For now I only want to look at Deschutes county. Using the .loc attribute of the data frame I can make a new subset of the data frame which is still a data frame. In the data frame I pick a column identifier and only keep the data if it meets a particular characteristic. In this case I want only data points which have 'Deschutes' in the county column.
#
# Below is a slightly more complex filter to illustrate some possibilities that I may need in the future. ([thanks to geeksforgeeks for the web tutorial!](https://www.geeksforgeeks.org/filter-pandas-dataframe-with-multiple-conditions/))
#
# ```
# # assign data
# dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
#                                    '  ROSS    ', 'CHANDLER', ' JOEY    '],
#
#                           'Age': [30, 35, 37, 33, 34, 30],
#
#                           'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
#
#                           'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
#                                   'IT', 'ARTIST']})
# # filter dataframe
# display(dataFrame.loc[(dataFrame['Salary']>=100000) & (dataFrame['Age']< 40) & (dataFrame['JOB'].str.startswith('D')),
#                     ['Name','JOB']])
# ```
#
# [pandas dataframe.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)

# %%
dataDeschutes = dataSet.loc[(dataSet['county'] == 'Deschutes')]
display(dataDeschutes)
# dataOregon = dataSet.loc[(dataSet['state']== 'Oregon')]
# display(dataOregon)
# Out:
#              date     county   state     fips  cases  deaths
# 2235   2021-04-04  Deschutes  Oregon  41017.0   6456    70.0
# 5484   2021-04-05  Deschutes  Oregon  41017.0   6470    70.0
# 8732   2021-04-06  Deschutes  Oregon  41017.0   6504    71.0
# 11981  2021-04-07  Deschutes  Oregon  41017.0   6535    72.0
# 15230  2021-04-08  Deschutes  Oregon  41017.0   6581    72.0
# 18478  2021-04-09  Deschutes  Oregon  41017.0   6633    72.0
# 21726  2021-04-10  Deschutes  Oregon  41017.0   6706    72.0
# 24975  2021-04-11  Deschutes  Oregon  41017.0   6741    72.0
# 28222  2021-04-12  Deschutes  Oregon  41017.0   6759    72.0
# 31470  2021-04-13  Deschutes  Oregon  41017.0   6793    72.0
# 34718  2021-04-14  Deschutes  Oregon  41017.0   6877    72.0
# 37965  2021-04-15  Deschutes  Oregon  41017.0   6929    72.0
# 41213  2021-04-16  Deschutes  Oregon  41017.0   6987    72.0
# 44461  2021-04-17  Deschutes  Oregon  41017.0   7082    72.0
# 47709  2021-04-18  Deschutes  Oregon  41017.0   7129    72.0
# 50956  2021-04-19  Deschutes  Oregon  41017.0   7172    72.0
# 54203  2021-04-20  Deschutes  Oregon  41017.0   7214    72.0
# 57451  2021-04-21  Deschutes  Oregon  41017.0   7312    72.0
# 60698  2021-04-22  Deschutes  Oregon  41017.0   7368    72.0
# 63945  2021-04-23  Deschutes  Oregon  41017.0   7472    73.0
# 67192  2021-04-24  Deschutes  Oregon  41017.0   7551    73.0
# 70439  2021-04-25  Deschutes  Oregon  41017.0   7635    73.0
# 73686  2021-04-26  Deschutes  Oregon  41017.0   7676    73.0
# 76933  2021-04-27  Deschutes  Oregon  41017.0   7756    73.0
# 80180  2021-04-28  Deschutes  Oregon  41017.0   7822    73.0
# 83427  2021-04-29  Deschutes  Oregon  41017.0   7949    73.0
# 86674  2021-04-30  Deschutes  Oregon  41017.0   8029    73.0
# 89921  2021-05-01  Deschutes  Oregon  41017.0   8116    73.0
# 93168  2021-05-02  Deschutes  Oregon  41017.0   8182    73.0
# 96416  2021-05-03  Deschutes  Oregon  41017.0   8231    73.0

# %% [markdown]
# ### Refer to ReadCSVtest.ipynb:
#
# For more detail about data frame attributes see the above noted notebook for reference. I will limit my comments here to what is needed to display Oregon COVID data here.

# %% [markdown]
# ### Converting Dates:
#
# Dates in data files come in a number of formats and often need to be converted to provide meaningful information. At some point I will need to figure out a better way to do this but for now I'm going to convert the european style date to a datetime object that pandas understands and then convert that datetime object to the day number of the year so I can plot sequentially.

# %%
dateRaw = dataDeschutes['date']
dateDay = pd.to_datetime(dateRaw, format = "%Y-%m-%d") 
print("After conversion, the type is : ", type(dateDay))
dayNum = dateDay.dt.dayofyear
dayNum
# Out:
# After conversion, the type is :  <class 'pandas.core.series.Series'>
# 2235      94
# 5484      95
# 8732      96
# 11981     97
# 15230     98
# 18478     99
# 21726    100
# 24975    101
# 28222    102
# 31470    103
# 34718    104
# 37965    105
# 41213    106
# 44461    107
# 47709    108
# 50956    109
# 54203    110
# 57451    111
# 60698    112
# 63945    113
# 67192    114
# 70439    115
# 73686    116
# 76933    117
# 80180    118
# 83427    119
# 86674    120
# 89921    121
# 93168    122
# 96416    123
# Name: date, dtype: int64

# %% [markdown]
# ### Comparison with Day # vs Date:
#
# The next two plots illustrate the difference between plotting the data using the day number and the raw date from the .csv file.
#
# #### Rotation of Dates:
#
# After some exploration I wondered if I could fix the messy date plotting that you see in the second plot below. I eventually found that I can rotate the plot labels on any axis which alllows the date, which is a long object, to be plotted vertically without overlapping with the adjacent labels. Cool!

# %%
# code cell that creates the plot
dataCases = dataDeschutes['cases']
fig1, ax1 = plt.subplots()
ax1.scatter(dayNum, dataCases)

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('Cummulative COVID Deschutes County', fontsize = 20)

fig1.set_size_inches(10, 9)
ax1.grid()

#fig.savefig("myplot.png")
plt.show()

# %%
# dates NOT rotated -- messy
# code cell that creates the plot
dataCases = dataDeschutes['cases']
fig2, ax2 = plt.subplots()
ax2.scatter(dateRaw, dataCases)

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('Cummulative COVID Deschutes County', fontsize = 20)

# size the figure
fig2.set_size_inches(10, 9)
ax2.grid()

#fig.savefig("myplot.png")
plt.show()

# %%
# dates rotated -- NICE
# code cell that creates the plot
dataCases = dataDeschutes['cases']
fig3, ax3 = plt.subplots()
ax3.scatter(dateRaw, dataCases)

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('Cummulative COVID Deschutes County', fontsize = 20)

# rotate the x tick labels so dates are readable
plt.xticks(rotation = '90')

# size the figure
fig3.set_size_inches(10, 9)
ax3.grid()

#fig.savefig("myplot.png")
plt.show()

# %% [markdown]
# ### Finding Daily Cases:
#
# The data set contains the cummulative case data. Epidemiologists have been focusing on the daily case numbers. The daily case number is the difference between each data point and the previous data point. This is a very common feature of data that folks are interested in and not surprisingly pandas and the pandas dataframe have a tool for that. This is another 'attribute' of the data frame called [pandas.DataFrame.diff](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.diff.html). It can do a variety of calculations but the default is to take the difference between successive data points.
#
# I can also add this data to the data frame by defining a new column
#
# Pandas is complaining about something I'm doing but I haven't figured it out yet. It still works but pandas is unhappy and I'll need to sort that out eventually.

# %%
dataDeschutes.loc['daily'] = dataDeschutes['cases'].diff()
dataDeschutes['3day'] = dataDeschutes['cases'].diff(periods=3)
dataDeschutes
# Out:
# <ipython-input-69-7151a5c6e367>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataDeschutes['3day'] = dataDeschutes['cases'].diff(periods=3)
#              date     county   state     fips   cases  deaths  daily   3day
# 2235   2021-04-04  Deschutes  Oregon  41017.0  6456.0    70.0    NaN    NaN
# 5484   2021-04-05  Deschutes  Oregon  41017.0  6470.0    70.0   14.0    NaN
# 8732   2021-04-06  Deschutes  Oregon  41017.0  6504.0    71.0   34.0    NaN
# 11981  2021-04-07  Deschutes  Oregon  41017.0  6535.0    72.0   31.0   79.0
# 15230  2021-04-08  Deschutes  Oregon  41017.0  6581.0    72.0   46.0  111.0
# 18478  2021-04-09  Deschutes  Oregon  41017.0  6633.0    72.0   52.0  129.0
# 21726  2021-04-10  Deschutes  Oregon  41017.0  6706.0    72.0   73.0  171.0
# 24975  2021-04-11  Deschutes  Oregon  41017.0  6741.0    72.0   35.0  160.0
# 28222  2021-04-12  Deschutes  Oregon  41017.0  6759.0    72.0   18.0  126.0
# 31470  2021-04-13  Deschutes  Oregon  41017.0  6793.0    72.0   34.0   87.0
# 34718  2021-04-14  Deschutes  Oregon  41017.0  6877.0    72.0   84.0  136.0
# 37965  2021-04-15  Deschutes  Oregon  41017.0  6929.0    72.0   52.0  170.0
# 41213  2021-04-16  Deschutes  Oregon  41017.0  6987.0    72.0   58.0  194.0
# 44461  2021-04-17  Deschutes  Oregon  41017.0  7082.0    72.0   95.0  205.0
# 47709  2021-04-18  Deschutes  Oregon  41017.0  7129.0    72.0   47.0  200.0
# 50956  2021-04-19  Deschutes  Oregon  41017.0  7172.0    72.0   43.0  185.0
# 54203  2021-04-20  Deschutes  Oregon  41017.0  7214.0    72.0   42.0  132.0
# 57451  2021-04-21  Deschutes  Oregon  41017.0  7312.0    72.0   98.0  183.0
# 60698  2021-04-22  Deschutes  Oregon  41017.0  7368.0    72.0   56.0  196.0
# 63945  2021-04-23  Deschutes  Oregon  41017.0  7472.0    73.0  104.0  258.0
# 67192  2021-04-24  Deschutes  Oregon  41017.0  7551.0    73.0   79.0  239.0
# 70439  2021-04-25  Deschutes  Oregon  41017.0  7635.0    73.0   84.0  267.0
# 73686  2021-04-26  Deschutes  Oregon  41017.0  7676.0    73.0   41.0  204.0
# 76933  2021-04-27  Deschutes  Oregon  41017.0  7756.0    73.0   80.0  205.0
# 80180  2021-04-28  Deschutes  Oregon  41017.0  7822.0    73.0   66.0  187.0
# 83427  2021-04-29  Deschutes  Oregon  41017.0  7949.0    73.0  127.0  273.0
# 86674  2021-04-30  Deschutes  Oregon  41017.0  8029.0    73.0   80.0  273.0
# 89921  2021-05-01  Deschutes  Oregon  41017.0  8116.0    73.0   87.0  294.0
# 93168  2021-05-02  Deschutes  Oregon  41017.0  8182.0    73.0   66.0  233.0
# 96416  2021-05-03  Deschutes  Oregon  41017.0  8231.0    73.0   49.0  202.0
# daily         NaN        NaN     NaN      NaN     NaN     NaN    NaN    NaN

# %%
# daily case data
# code cell that creates the plot
dataDaily = dataDeschutes['daily']
fig4, ax4 = plt.subplots()
ax4.scatter(dateRaw, dataDaily)

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('Daily Cases COVID Deschutes County', fontsize = 20)

# rotate the x tick labels so dates are readable
plt.xticks(rotation = '90')

# size the figure
fig4.set_size_inches(10, 9)
ax4.grid()

#fig.savefig("myplot.png")
plt.show()

# %%
# 3 day rolling average
# code cell that creates the plot
data3Day = dataDeschutes['3day']
fig5, ax5 = plt.subplots()
ax5.scatter(dateRaw, data3Day/3)

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('3 Day Average COVID Deschutes County', fontsize = 20)

# rotate the x tick labels so dates are readable
plt.xticks(rotation = '90')

# size the figure
fig5.set_size_inches(10, 9)
ax5.grid()

#fig.savefig("myplot.png")
plt.show()

# %% [markdown]
# ### Last Thing: Oregon Case Criteria
#
# Since we are currently wrestling with higher risk in Deschutes County I wondered if I could verify the state data that places Deschutes county in the high risk category. The [criteria that Oregon uses are listed on this webpage](https://coronavirus.oregon.gov/Pages/living-with-covid-19.aspx). As a county with a population of more than 30,000 (population of Deschutes county is pegged at 198,000 for 2019 - call it 200,000 for 2020) the case rate criteria is based on case rate per 100,000 over 14 days. It is not entirely clear what the 'over 14 days' which is partly what I'm curious about.
#
# https://coronavirus.oregon.gov/Pages/living-with-covid-19.aspx

# %%
peopleDeschutes = 200000.0
rateDivider = peopleDeschutes/100000.0
rateDivider
# Out:
# 2.0

# %%
# 3 day rolling rate 
# code cell that creates the plot
# divide by 3 to get rolling average
# divide by rateDivider to get rate/100,000 population
rate3Day = dataDeschutes['3day']/(3*rateDivider)
fig6, ax6 = plt.subplots()
ax6.scatter(dateRaw, rate3Day)

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('3 Day Average COVID Deschutes County', fontsize = 20)

# rotate the x tick labels so dates are readable
plt.xticks(rotation = '90')

# size the figure
fig6.set_size_inches(10, 9)
ax6.grid()

#fig.savefig("myplot.png")
plt.show()

# %% [markdown]
# ### What We Can Learn:
#
# The rate/100,000 averaged over 3 days has stayed below 50 for all of April according to this data. That would appear to put us in a moderate risk category. On the other hand the state has placed us in the extreme risk category according to the website linked above. How can this be? The value in looking at the actual data is that it makes us think! It is likely that what the criteria means is that the **TOTAL CASES/100,000 over 14 days** is what is being assessed.
#
# Let's imagine that is what is being measured. Stated another way 200 cases/100,000 over 14 days is and 14.28 cases/100,000 each day for 14 days. Reframing the state criteria this way allows us to put reference lines on the graph. Here are the locations of the dividing lines between the criteria IF that is what is meant:
#
# 1. 50 cases/100,000 => 3.57 cases/100,000/day
# 1. 100 cases/100,000 => 7.14 cases/100,000/day
# 1. 200 cases/100,000 => 14.28 cases/100,000/day

# %%
# 3 day rolling rate with Oregon Criteria
# code cell that creates the plot
# divide by 3 to get rolling average
# divide by rateDivider to get rate/100,000 population
rateLow = 3.57
rateModerate = 7.14
rateHigh = 14.28
rate3Day = dataDeschutes['3day']/(3*rateDivider)
fig6, ax6 = plt.subplots()
ax6.scatter(dateRaw, rate3Day)

ax6.hlines(rateLow, 0, 30,
         color = 'green', linestyle = '-',
         linewidth = 2., label = "low risk")
ax6.hlines(rateModerate, 0, 30,
         color = 'yellow', linestyle = '-',
         linewidth = 2., label = "moderate risk")
ax6.hlines(rateHigh, 0, 30,
         color = 'red', linestyle = '-',
         linewidth = 2., label = "high risk")

# a more explicit way to set labels
plt.xlabel('Date', fontsize = 10)
plt.ylabel('Cases', fontsize = 10)
plt.title('Average Rate/100,000 COVID Deschutes County', fontsize = 20)

# rotate the x tick labels so dates are readable
plt.xticks(rotation = '90')

# show labels
plt.legend(loc= 2)

# size the figure
fig6.set_size_inches(10, 9)
ax6.grid()

#fig.savefig("myplot.png")
plt.show()

# %% [markdown]
# ### Reflections:
#
# I gotta stop now but I feel like this is an example of an important learning experience with data and science. When you have the actual data you can dig into it to develop a greater understanding. I'm not sure that I have this figured out yet but I have much better questions to ask. Based on this analysis I am surprised that Deschutes County is stepping down from 'extreme risk' next week. The data on the Oregon website indicates we have 467 cases/100,000/14 days which is 33 cases/100,000/day and that matches the data above. Boom!
#
# Done for now. Happy exploring:)
